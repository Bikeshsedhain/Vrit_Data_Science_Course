# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# Generate x values for the standard normal distribution
x = np.linspace(-6,6,1000)

# Calculate the critical z-scores
z_critical = stats.norm.ppf(1-0.05/2)
print(z_critical)

#plot the standard normal distribution

plt.figure(figsize = (4,4))
plt.plot(x,stats.norm.pdf(x), 'black', lw = 1, label='Standard Normal Distribution')

#Shade the rejection region

plt.fill_between(x,stats.norm.pdf(x), where = (x<=-z_critical) | (x>= z_critical), color = 'red', alpha = 1, label= 'Rejection Region')

# Add labels and title
plt.title('Standard Normal Distribution with Rejection Region')
plt.xlabel('Z-score')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# 1.959963984540054

# %% [markdown]
#  ## Perform Test Statistic and Calculate P-value

# %%
# Sample data (weights)
sample = [150, 155,160,165,170,175,180]

# Sample statistics
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof = 1)
sample_size = len(sample)

# Hypothesis mean 

mu_0 = 164

# Calculate the z-score
z_score = (sample_mean - mu_0)/(sample_std / np.sqrt(sample_size))

# Calculate the p-value
p_value = 2 * (1-stats.norm.cdf(np.abs(z_score)))

# %%
print(p_value)
# Out:
# 0.80649594050734

# %%
if p_value <= 0.05:
    conclusion = 'Reject H0'
else:
    conclusion = 'There is insufficient evidence to support that the mean weight is different from 164'
print(conclusion)
# Out:
# There is insufficient evidence to support that the mean weight is different from 164
